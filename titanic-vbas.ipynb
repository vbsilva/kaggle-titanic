# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading data

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
#data = pd.concat([train, test], sort=False)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## Explore data

# %%
plt.figure(dpi=180)
sns.heatmap(train.corr(), annot=True)
# heatmap get around plot bug
x = plt.ylim()
plt.ylim(x[0]+0.5, x[1]-0.5)
plt.show()

# %% [markdown]
# ### PassengerId

# %%
passenger_id_header = 'PassengerId'
print('var:', train[passenger_id_header].var())
print('std:', train[passenger_id_header].std())
# Out:
# var: 66231.0
# std: 257.3538420152301

# %% [markdown]
# > very **low correlation** with 'Survived' Feature and very high var and std. So this feature will not be included
